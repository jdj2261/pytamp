# %% [markdown]
# # Load Package

# %%
import numpy as np
import matplotlib.pyplot as plt
from pykin.utils import plot_utils as p_utils
# %matplotlib inline

# %%
def linearplot_with_confidence(x_list, error_list, label, marker="", color='r'):
    mean_list = np.squeeze(np.mean(error_list,axis=0))
    std_list = np.std(error_list,axis=0)
    a = 0.1
    plt.fill_between(x_list, mean_list-a*std_list,mean_list+a*std_list, alpha=0.13, color=color)
    plt.plot(x_list,mean_list,label=label,marker=marker, ms=11, c=color, markevery=15)

# %% [markdown]
# # Unit Plot

# %% [markdown]
# - Bai Perturbation

# %%
seeds=5
budgets = 100
end_num = 0
algo = "bai_perturb"

perturb_final_level_1_values = [[] for _ in range(seeds)]
perturb_final_level_2_values = [[] for _ in range(seeds)]
perturb_final_pnp_all_joint_paths = [[] for _ in range(seeds)]
c_list = [[] for _ in range(seeds)]

for seed in range(1, seeds+1):
    filename = f'benchmark1_result/benchmark1_test_algo({algo})_budget({budgets})_seed({seed})_{end_num}.npy'

    try:
        with open(filename,'rb') as f:
            data_for_seed = np.load(f, allow_pickle=True)
            perturb_final_level_1_values[seed-1].append(data_for_seed['level_1_values'])
            perturb_final_level_2_values[seed-1].append(data_for_seed['level_2_values'])
            perturb_final_pnp_all_joint_paths[seed-1].append(data_for_seed['pnp_all_joint_paths'])
            c_list[seed-1] = data_for_seed['c']
    
    except FileNotFoundError as f:
        print(f)

# %%
fig, ax = p_utils.init_2d_figure("test")

seed = 1
for idx, c in enumerate(c_list[seed-1]):
    p_utils.plot_values(
        ax,
        perturb_final_level_1_values[seed-1][0][idx], 
        label=f"c({c})", 
        title=f"Benchamrk1_Level_1 Seed[{seed}]", 
        save_dir_name='benchmark1_result', 
        is_save=False)

# %% [markdown]
# - UCT

# %%
seeds=5
budgets = 100
end_num = 0
algo = "uct"
fig, ax = p_utils.init_2d_figure("test")

for seed in range(1, seeds+1):
    filename = f'benchmark1_result/benchmark1_test_algo({algo})_budget({budgets})_seed({seed})_{end_num}.npy'

    perturb_final_level_1_values = []
    perturb_final_level_2_values = []
    perturb_final_pnp_all_joint_paths = []

    try:
        with open(filename,'rb') as f:
            data_for_seed = np.load(f, allow_pickle=True)
            perturb_final_level_1_values.append(data_for_seed['level_1_values'])
            perturb_final_level_2_values.append(data_for_seed['level_2_values'])
            perturb_final_pnp_all_joint_paths.append(data_for_seed['pnp_all_joint_paths'])
            c_list = data_for_seed['c']
        
        mean_result = np.mean(perturb_final_level_1_values[0], axis=0)
        p_utils.plot_values(
            ax,
            mean_result, 
            label=f"seed({seed})", 
            title="Benchamrk1_Level_1", 
            save_dir_name='benchmark1_result', 
            is_save=False)
    except FileNotFoundError as f:
        print(f)

# %% [markdown]
# - random

# %%
seeds=5
budgets = 100
end_num = 0
algo = "random"
fig, ax = p_utils.init_2d_figure("test")

for seed in range(1, seeds+1):
    filename = f'benchmark1_result/benchmark1_test_algo({algo})_budget({budgets})_seed({seed})_{end_num}.npy'

    perturb_final_level_1_values = []
    perturb_final_level_2_values = []
    perturb_final_pnp_all_joint_paths = []

    try:
        with open(filename,'rb') as f:
            data_for_seed = np.load(f, allow_pickle=True)
            perturb_final_level_1_values.append(data_for_seed['level_1_values'])
            perturb_final_level_2_values.append(data_for_seed['level_2_values'])
            perturb_final_pnp_all_joint_paths.append(data_for_seed['pnp_all_joint_paths'])
            c_list = data_for_seed['c']
        
        mean_result = np.mean(perturb_final_level_1_values[0], axis=0)
        p_utils.plot_values(
            ax,
            mean_result, 
            label=f"seed({seed})", 
            title="Benchamrk1_Level_1", 
            save_dir_name='benchmark1_result', 
            is_save=False)
    except FileNotFoundError as f:
        print(f)

# %% [markdown]
# - bai-ucb

# %%
seeds=5
budgets = 100
end_num = 0
algo = "bai_ucb"
fig, ax = p_utils.init_2d_figure("test")

for seed in range(1, seeds+1):
    filename = f'benchmark1_result/benchmark1_test_algo({algo})_budget({budgets})_seed({seed})_{end_num}.npy'

    perturb_final_level_1_values = []
    perturb_final_level_2_values = []
    perturb_final_pnp_all_joint_paths = []

    try:
        with open(filename,'rb') as f:
            data_for_seed = np.load(f, allow_pickle=True)
            perturb_final_level_1_values.append(data_for_seed['level_1_values'])
            perturb_final_level_2_values.append(data_for_seed['level_2_values'])
            perturb_final_pnp_all_joint_paths.append(data_for_seed['pnp_all_joint_paths'])
            c_list = data_for_seed['c']
        
        mean_result = np.mean(perturb_final_level_1_values[0], axis=0)
        p_utils.plot_values(
            ax,
            mean_result, 
            label=f"seed({seed})", 
            title="Benchamrk1_Level_1", 
            save_dir_name='benchmark1_result', 
            is_save=False)
    except FileNotFoundError as f:
        print(f)
